# %% [markdown]
# ## 구글 코랩(Google Colab) 익숙해지기!
# > **아래 매뉴얼을 따라해주세요!**
# > - 이 셀을 한 번 클릭한 후, 화면 좌측 상단의 '**+텍스트**' 버튼을 눌러보세요.

# %% [markdown]
# 텍스트를 입력할 수 있습니다.
# - 설명 용도가 될 수 있습니다.
# - 학습을 위한 메모 기능으로 활용할 수 있습니다.

# %% [markdown]
# > - 해당 셀이 비어있어서 '더블 클릭 또는 Enter 키를 눌러 수정'이라고 쓰여 있을 것입니다.
# - 생성된 셀을 더블 클릭한 뒤, '화이팅'을 입력한 뒤 `shift + enter`를 눌러주세요.

# %% [markdown]
# - 이 셀을 한 번 클릭한 후, 화면 좌측 상단의 '**+코드**' 버튼을 눌러보세요.

# %%
코드를 입력할 수 있는 셀입니다.
# Out:
#   File "<ipython-input-1-caa4efbf2124>", line 1
#     코드를 입력할 수 있는 셀입니다.
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# > - 코드를 입력할 수 있는 셀이 추가되었습니다!!
# > - 이제 해당 셀을 '**더블 클릭**'하거나 '**엔터키**'를 치고 편집 환경에 들어갑니다.
# > - 우측 상단의 툴박스를 통해 셀을
#     1.   위로 올리거나
#     2.   아래로 내리거나
#     3. 링크를 공유하거나
#     4. 댓글을 달거나
#     5. 삭제할 수 있습니다.

# %% [markdown]
# 😎코랩 사용 tip 몇 가지!
#
#
# > [ 단축키 ]
#
# - ESC + A : 위에 코드 셀 생성
# - ESC + B : 아래에 코드 셀 생성
# - ctrl(cmd) + M + D : 셀 삭제
# - shift + enter : 코드 셀 실행!

# %% [markdown]
# # 📌 Step 1. 파이썬 기초
# # 파이썬은 이런말을 알아들을 수 있어요

# %% [markdown]
# ## 1. 주석
#
# 주석(코멘트)는 컴퓨터가 읽지 않도록 하는 마법의 기능입니다.
# > '#' 을 입력 후 원하는 내용을 입력할 수 있습니다.
#
# ```
# # 서대문구 화이팅~
# ```
#
#
#
# ```
# # 더하기를 해주는 함수 코드
# add()
# ```

# %%
# 123213  -> CTRL + /
# 123
# 코딩을 설명하는 노트 테이킹을 할 수 있습니다.
print("프로그래밍")
# Out:
# 프로그래밍

# %%
주석 달아보기(에러가 나지않게 주석을 달아보세요!)
# Out:
#   File "<ipython-input-3-08bd3ac07513>", line 1
#     주석 달아보기(에러가 나지않게 주석을 달아보세요!)
#           ^
# SyntaxError: invalid syntax

# %%
#@title 정답
# 주석 달아보기(에러가 나지않게 주석을 달아보세요!)

# %%
## 1. 여러 줄 주석 

# 파이썬에서 여러 줄 주석을 달기 위해서는 ''' '''를 사용합니다.
# ''' ''' 사이에 원하는 내용을 입력할 수 있습니다.

'''
서대문구 화이팅
파이썬 화이팅
'''
# Out:
#   File "<ipython-input-1-b0506215d513>", line 3
#     파이썬에서 여러 줄 주석을 달기 위해서는 ''' '''를 사용합니다.
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2. 출력 Print
#
# 코드는 컴퓨터와 소통하는 방법입니다.
# 요즘은 인공지능 스피커가 나와서 다양한 방식으로 소통할 수 있겠지만, 우리가 보는 코드 화면은 흰 바탕에 검정 글씨로 쓰인 워드 화면과 크게 다르지 않습니다.
#
# **`print()`** 는 컴퓨터가 말하도록 하는 함수입니다. 이때 화면 상에 출력되는 결과를 보통 **`output`**, 또는 코드의 출력이라고 합니다.
#
# <img src="https://1.bp.blogspot.com/-6xslfGdg9So/XoF757SbMMI/AAAAAAAAAN0/2SfYDCN2KSMsIUwc0sQwriAgvq7KJl3dgCLcBGAsYHQ/s1600/1%25E1%2584%2580%25E1%2585%25A1%25E1%2586%25BC%2B%25E1%2584%2591%25E1%2585%25B3%25E1%2584%2585%25E1%2585%25B5%25E1%2586%25AB%25E1%2584%2590%25E1%2585%25B3%2B%25E1%2584%2592%25E1%2585%25A1%25E1%2586%25B7%25E1%2584%2589%25E1%2585%25AE.jpg" width = "700">
#
# 아래와 같이 괄호 안에 다양한 메세지 또는 변수들을 넣어서 원하는 것을 출력하도록 할 수 있습니다.

# %%
# print()
print("안녕하세요!")       # 문자를 넣을 수도 있고
print(10)               # 숫자를 넣을 수도 있고
print(False)            # 참/거짓 값을 넣을 수도 있습니다.
# Out:
# 안녕하세요!
# 10
# False

# %% [markdown]
# ## 3. 변수 Variables
#
# **변수**란 프로그래밍에서 **데이터를 저장하는 공간**입니다.
#
#
# 변수를 활용하면 한 번 지정한 값을 여러 번 재사용할 수 있으므로 코딩하기가 편해집니다.
#
# 변수를 어떠한 값으로 지정하는 것을 파이썬에서는 **선언 (assign)** 이라 하며 다음과 같이 **'='** 부호를 사용합니다.
#
# <img src = "https://1.bp.blogspot.com/-t5-w7IhWPGI/XoF9eA43NTI/AAAAAAAAAOg/JQ87XAQwjGwN4f15SIk7THPiu6m7i0PHACLcBGAsYHQ/s1600/%25E1%2584%258F%25E1%2585%25A2%25E1%2586%25B8%25E1%2584%258E%25E1%2585%25A54.JPG" width = "550">

# %%
# 변수를 이용하면 매번 장문의 데이터를 입력할 필요가 없어집니다.
sentence = "회사 가기 싫다"

print(sentence)
# Out:
# 회사 가기 싫다

# %% [markdown]
# ## 4. 변수 이름 짓기
# 변수의 이름은 여러분 마음대로 지정할 수 있습니다.
# 다만 띄어쓰기는 인식이 불가능하니 여러 형태로 띄어쓰기를 대체하고 있습니다.
#
# 파이썬에서는 보통 언더바 `_` 혹은 대문자로 띄어쓰기를 대체합니다.
#
#
#
# 또한, 한 번 선언한 변수의 값은 다시 선언 기호 `=` 를 사용하여 다른 값으로 업데이트할 수 있습니다.
#
#
# 다음과 같이요 !
#
# > 아래의 예제에서 칼로리 섭취량을 수정해보세요.

# %%
# 칼로리 섭취량 계산
lunch = 390 # lunch 라는 변수에 390이라는 숫자를 할당하라 (컴퓨터에게 전달)
lemon_juice = 40 # Snake Case
cheeseCake = 60 # Camel Case 

# 칼로리 섭취량 출력
print("점심 : ", lunch) # lunch라는 변수에 무슨 값이 있는지 보여줘
print("레몬 쥬스 : ", lemon_juice)# lemon_juice라는 변수에 무슨 값이 있는지 보여줘 
print("치즈 케익 : ", cheeseCake)# cheeseCake라는 변수에 무슨 값이 있는지 보여줘 

# 레몬 쥬스의 칼로리를 60으로 변경하라.
# cheeseCake의 칼로리를 80으로 변경하라.

####################################
# 코드를 작성하시오.

####################################

₩
# 칼로리 섭취량 출력
print("점심 : ", lunch) # lunch라는 변수에 무슨 값이 있는지 보여줘
print("레몬 쥬스 : ", lemon_juice)# lemon_juice라는 변수에 무슨 값이 있는지 보여줘 
print("치즈 케익 : ", cheeseCake)# cheeseCake라는 변수에 무슨 값이 있는지 보여줘
# Out:
# 점심 :  390
# 레몬 쥬스 :  40

# %%
#@title 정답
# 칼로리 섭취량 계산
lunch = 390 # lunch 라는 변수에 390이라는 숫자를 할당하라 (컴퓨터에게 전달)
lemon_juice = 40 # Snake Case
cheeseCake = 60 # Camel Case 

# 칼로리 섭취량 출력
print("점심 : ", lunch) # lunch라는 변수에 무슨 값이 있는지 보여줘
print("레몬 쥬스 : ", lemon_juice)# lemon_juice라는 변수에 무슨 값이 있는지 보여줘 
print("치즈 케익 : ", cheeseCake)# cheeseCake라는 변수에 무슨 값이 있는지 보여줘 

# 레몬 쥬스의 칼로리를 60으로 변경하라.
# cheeseCake의 칼로리를 80으로 변경하라.

####################################
# 코드를 작성하시오.
lemon_juice = 60
cheeseCake = 80
####################################

# 칼로리 섭취량 출력
print()
print("점심 : ", lunch) # lunch라는 변수에 무슨 값이 있는지 보여줘
print("레몬 쥬스 : ", lemon_juice)# lemon_juice라는 변수에 무슨 값이 있는지 보여줘 
print("치즈 케익 : ", cheeseCake)# cheeseCake라는 변수에 무슨 값이 있는지 보여줘

# %% [markdown]
# ## 5. 문자열 String
#
# 컴퓨터 프로그래밍에서 텍스트를 **문자열(string)** 이라고 부릅니다.
#
#
# 파이썬에서는 문자열을 **큰 따옴표** 또는 **작은 따옴표**로 표기합니다.
#
#
# 예) "이것은 문자열(string)입니다" or '이것 또한 문자열(string)입니다'
#
#
# 어떤 따옴표를 쓰는지는 상관없습니다! 다만 짝이 맞아야 해요.
#
# > 🔍 아래의 빈 셀에서 본인의 이름을 print()함수를 이용하여 출력해보세요! 한번은 `" " `, 한번은 `' ' `을 써주시기 바랍니다.

# %%
#이름을 출력해보세요... 두 번...!!
? # 큰 따옴표 문자열로 자신의 이름을 출력해라
? # 작은 따옴표 문자열로 자신의 이름을 출력해라

# %%
#@title 정답 { display-mode: "form" }

#이름을 출력해보세요... 두 번...!!
print("김민규") # 큰 따옴표 문자열로 자신의 이름을 출력해라
print('김민규') # 작은 따옴표 문자열로 자신의 이름을 출력해라

# %%
# 큰 따옴표와 작은 따옴표를 사용해서 자신의 이름을 소개하기
print('저의 이름은 "김민규" 입니다')
print("저의 이름은 '김민규' 입니다.")

# 역슬래쉬를 사용해서 따옴표 사용 가능
print("저의 이름은 \"김민규\" 입니다.")

# %% [markdown]
# 포맷팅의 방법은 2가지입니다.
# 1. 포맷 코드 사용 (%d, %s 등)
# 2. 포맷 함수 사용 ( { } .format )

# %% [markdown]
# 포맷 코드 사용자료 형태에 따라서 사용하는 포맷코드가 다릅니다.
# 1. %s : 문자열 ◀ 많이 사용
# 2. %d : 정수 ◀ 많이 사용
# 3. %c : 문자 1개
# 4. %f : 부동 소수
# 6. %o : 8진수
# 7. %x : 16진수

# %%
sentence = "안녕하세요"
integer = 35
decimal = 2.3
grade = 'A'
integer = 27
score = 4

print("문장 : %s" % sentence)
print("정수 : %d" % integer)
print("학점 : %c" % grade)
print("소수 : %f" % real_number)
print("8진수 : %o" % integer)
print("16진수 : %x" % integer)
print("%s의 점수는 %d" %(grade, score))
# Out:
# 문장 : 안녕하세요
# 정수 : 27
# 학점 : A
# 소수 : 4.500000
# 8진수 : 33
# 16진수 : 1b
# A의 점수는 4

# %% [markdown]
# 포맷 코드는 자료 형태에 따라서
# %s, %d, %f 등으로 써야 한다고 말씀드렸는데요.
# ​
# Tip!  문자열에 사용되는 %s 는
# 어떤 자료 형태로도 치환이 가능합니다.
# 모든자료를 문자열로 바꿔서 출력하기 때문입니다.
# (자료형태를 유지할 필요가 없다면 %s만 사용해도 됩니다.)

# %%
integer = 35
decimal = 2.3

print("정수: %s, 실수: %s" %(integer, decimal))
# Out:
# 정수: 35, 실수: 2.3

# %% [markdown]
# 문자열 내에서 포맷팅 하려는 값을
#  {0} 부터 순서대로 입력합니다.
# 문자열 끝에 ' . format( ) ' 을 입력한 후
# 괄호 안에 순서대로 출력값을 넣습니다.

# %%
name = "김민규"
integer = 35
decimal = 2.3
grade = 'A'
integer = 27
score = 4

print("점수는 {0} 점 입니다." .format(score)) 
print("{0}의 점수는 A 입니다." .format("김민규")) 
print("{0}의 점수는 {1} 입니다." .format(name, grade)) 
print("{0}의 점수는 {1} 입니다. {2}" .format(name, grade, "졸업 성공!"))

# %% [markdown]
# ​
# 순서가 너무 많아져서 헷갈린다면
# format 함수 내에서 변수를 지정하여
# 값을 넣을 수도 있습니다.
# ​
# 헷갈릴 필요없이
# 가장 깔끔한 방법이라고 생각합니다~

# %%
점수=70 
print("{name}의 점수는 {score} 점 입니다." .format(name="민규", score=점수))
# Out:
# 민규의 점수는 70 점 입니다.

# %% [markdown]
# ## 6. 숫자 Numeric Data types
#
# 파이썬에서는 수를 크게 두 가지 타입으로 분류합니다 .
#
# 1. **integer 또는 int** 는 **정수형** 데이터를 저장하는 변수 타입입니다. (-2, -1 .... 3 4 5 등)
# 소수점이 없는 수를 저장할 때 쓰입니다.
#
# 2. **floating point 또는 float** 는 **부동소수점**을 표기하기 위해 쓰는 변수 타입입니다. ( 1.23, 10.567 등)
#
# 어떤 타입인지 모를 때는 **type()** 함수를 쓰면 알 수 있습니다.

# %%
type(1)
# Out:
# int

# %%
grade_1 = 3    #int 형 (정수) - 기본 설정
grade_2 = 2.0  #float 형 (실수)
 
# type(변수명)
print("grade_1 type : ") 
print(type(grade_1)) # 정수로 인식
print("grade_2 type : ")
print(type(grade_2)) # 실수로 인식
 
print("average :", grade_1/2 + grade_2/2)  #파이썬에서는 타입을 알아서 자동으로 변환해줍니다!
# grade_1 = 3
print(type(grade_1/2 + grade_2/2))
# Out:
# grade_1 type :
# <class 'int'>
# grade_2 type :
# <class 'float'>
# average : 2.5
# <class 'float'>

# %% [markdown]
# ## 7. 불 bool data types
#
# 파이썬에는 참(True), 거짓(False)를 나타내는 불(bool) 자료형도 있습니다.

# %%
# boolean: 참 (1) / 거짓 (0)

# '할당'을 해줄때는 =, 우리가 아는 '같다'의 뜻인 등호는 == 

print(True==1) # 변수명이 아니라, 예약어로 처리
print(True==0)
print("True")
print(type(True))
print(type(False))
# Out:
# True
# False
# True
# <class 'bool'>
# <class 'bool'>

# %%
type(True)
# Out:
# bool

# %%
var = "True"
type(var)
# Out:
# str

# %% [markdown]
# ### 🙌 여기서 잠깐! True, False는 예약어 !?
# 파이썬에는 이미 특정 기능을 수행할 수 있도록 키워드로 지정되어 있는 예약어(Reserve Words)가 있습니다. 예약어는 변수나 함수의 이름으로 사용될 수 없다는 특징이 있어요! True와 False도 예약어이기 때문에 변수나 함수 이름으로 사용하면 오류가 뜹니다!
