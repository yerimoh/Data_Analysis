# %% [markdown]
# # 📌 Step 2. 파이썬 계산
# # 파이썬은 이런 것들을 계산할 수 있어요

# %% [markdown]
# ### 1. 사칙연산
#
# 파이썬은 엑셀과 같은 함수 기호를 써서 연산합니다.
#
#  `print()` 안에 넣어도 잘 동작하고
# `=`으로 선언할 때 써도 잘 동작합니다!
# 제곱은 `**` 으로 표기합니다.

# %%
# 출력값을 예상헤보세요
1+1
# Out:
# 2

# %%
# 위랑 같은 코드를 입력해보세요
# 출력값이 2여야 함
print()

# %%
#@title 정답
print(1+1 )
# Out:
# 2

# %%
# 출력값을 예상헤보세요
2+2
# Out:
# 4

# %%
# print "100" 더하기 빼기
print(170 - 71 + 1)


# Print "50" 곱셈
print(25 * 2)


# Print "2.0" 나눗셈
# 슬래쉬 하나로 나누면 float(실수)를 반환한다
# 슬래쉬 두개로 나누면 int(정수)를 반환한다.
print(10 / 5)
print(10 // 5)

# Print "18.0" 나눗셈
num = 3*2/2*6
print(num)


# Print "2의 3승" 제곱
print(2 ** 3)
# Out:
# 100
# 50
# 2.0
# 2
# 18.0
# 8

# %% [markdown]
# > 0 으로 나누면 어떻게 될까요? 아래 셀을 실행해보세요

# %%
print(5/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-fad870a50e27> in <module>()
# ----> 1 print(5/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# > 🔍 아래의 셀에서 사각형의 넓이를 출력해보세요

# %%
width = 400
height = 200  

print(400*200) #여기서 넓이를 출력해보세요!

# print(400*200)말고 다른 방법으로도 풀어보세요!
print(width * height)
# Out:
# 80000
# 80000

# %%
width ** height
# Out:
# ...

# %% [markdown]
# **[Q 3]**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)출력값

# %%
# 정답

# %%
#@title 정답
a=10
b=3
c=1.5

print(a+b)
print(a-b)
print(a//b)
print(a%b)

b*=2
print(b)

a*=c
print(a)
# Out:
# 13
# 7
# 3
# 1
# 6
# 15.0

# %% [markdown]
# **[Q 1]**
#
# 파이썬에서는 나누었을 때 **나머지를 구해주는 기능**이 있습니다.
# `%`기호로 나머지를 구할 수 있는데요.
# ![소주 나누기 화질 좋은 ver.png](data:image/png;base64,...)

# %%
# 소주 2병을 10명이서 한 잔씩 마셨을 때, 남는 소주의 양은? 
# 힌트 소주 한 병은 7잔입니다 ^0^  

num_soju = 2
num_people = 10

leftover_soju = ❔

print("소주 2병을 10명이서 한 잔씩 마셨을 때, 남는 소주의 양은?")
print(leftover_soju, "잔")
# Out:
# 소주 2병을 10명이서 한 잔씩 마셨을 때, 남는 소주의 양은?
# 4 잔

# %%
#@title 정답
# 소주 2병을 10명이서 한 잔씩 마셨을 때, 남는 소주의 양은? 
# 힌트 소주 한 병은 7잔입니다 ^0^  

num_soju = 2
num_people = 10

leftover_soju = num_soju * 7 %10

print("소주 2병을 10명이서 한 잔씩 마셨을 때, 남는 소주의 양은?")
print(leftover_soju, "잔")

# %% [markdown]
# ## 2. 문자열 더하기 String Concatenation
#
# `+` 기호를 문자열(String)에 사용하면 놀라운 일이 일어납니다.
# 문자열끼리 덧셈이 가능해지는데요. 이것을 Concatenation 이라고 합니다.
# 문자열을 더하면 공백없이 두 문자열이 합쳐지게 됩니다. (순서는 더한 순서대로!)
#
# > 아래의 예제에서 lyrics 라는 변수에 모든 문자열을 더해주세요. 그 이후 lyrics 를 출력해주세요!

# %%
string_1 = "비가 내리고, "
string_2 = "음악이 흐르면, "
string_3 = "난 당신을 생각해요, "
string_4 = "당신이 떠나시던 그 밤에 이렇게 비가 왔어요 " 

lyrics = string_1 + string_2 + string_3 + string_4 # lyrics concatenate 하세요!
print(lyrics) # lyrics를 출력해보세요!😲
# Out:
# 비가 내리고, 음악이 흐르면, 난 당신을 생각해요, 당신이 떠나시던 그 밤에 이렇게 비가 왔어요

# %%
print("문자열을" + " 더해보았어요", 1)
# Out:
# 문자열을 더해보았어요 1

# %% [markdown]
# ## 3. += 이랑 -= Plus Equals
#
# 가끔 한 번 지정한 값을 업데이트 해줘야 할 때가 있습니다.
#  - `money = money + 10000`
#  - `money += 10000`
#
# 둘 다 현재의 money 에 10000 을 더해서 업데이트하여 줍니다.
# `-=` 기호를 쓰면 뺄셈이 되겠죠!

# %% [markdown]
# > 하루 칼로리 계산 예제 다시보기

# %%
# 하루 칼로리 계산 예제 다시보기 
lunch = 390
lemon_juice = 40
print(lunch)
# Out:
# 390

# %%
#1번 : lunch = lunch + lemon_juice
lunch += lemon_juice
print("오늘 먹은 칼로리는 ? ")
print(lunch)
# Out:
# 오늘 먹은 칼로리는 ?
# 510

# %% [markdown]
# > 🔍 (예시) 어제 국내 코로나 확진자 수는 1000명이었습니다.
# 오늘 100명의 환자가 퇴원했는데요,
# 그렇다면 오늘 코로나 확진자 수는 몇 명일지 **-= 기호를 사용하여** 구해보세요!

# %%
# 정답코드 작성

# %%
#@title 정답
patients = 1000   # 확진자 수
print("어제 확진자 수")
print(patients)

# 오늘 확진자 수로 변수 patients를 업데이트하세요.
patients -= 100
print("오늘 확진자 수")
print(patients)

# %% [markdown]
# > 🔍 다음 변수들을 만들어보세요  (한번 정리하고 가볼까요?)
# >
# >`first_name`
# `last_name`
# `full_name`
# `my_age`
# `half_my_age`
#
#   [출력되어야 하는 정보]
#
#     이름:
#     김마인
#     나이:
#     30

# %%
#문자열(String)
first_name = "Kanghee"
last_name = "Lee"

#문자열 더하기(String Connection)
print("이름:")
full_name = first_name + last_name
print(full_name)

#숫자(Numeric Data Types)
print("나이:")
my_age= 60
print(my_age)


#숫자 사칙연산 (+ - x %)
half_my_age = my_age // 2
print(half_my_age)
# Out:
# 이름:
# KangheeLee
# 나이:
# 60
# 30
